# %%
pip install -q langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 420.1/420.1 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.1 MB/s eta 0:00:00

# %%
# ChatOpenAI: This is the langchain wrapper for OpenAI chat models
from langchain_openai import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage, AIMessage
import os

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
# Initialize OpenAI chat model

chat_model = ChatOpenAI(
    model_name = "gpt-4o-mini",
    temperature = .8
)

# %%
message = [
    SystemMessage(content="You are a Langchain Expert."),
    HumanMessage(content="what is langchain?"),
    AIMessage(content="Langchain is an open source framework for Creating LLM applications."),
    HumanMessage(content="what are its key features?")
]

# %%
response = chat_model.invoke(message)

# %%
print(response.content)
# Out:
# Langchain offers several key features that make it a powerful framework for building applications that leverage large language models (LLMs). Some of its notable features include:
#
# 1. **Modularity**: Langchain is designed with modular components that allow developers to mix and match different functionalities, making it easy to customize LLM applications.
#
# 2. **Chains**: The framework supports the creation of "chains," which are sequences of calls to LLMs or other functions. This allows for more complex workflows and the ability to combine multiple steps in a single application.
#
# 3. **Agents**: Langchain provides support for building agents that can interact with LLMs to perform tasks based on user input dynamically. These agents can use tools and make decisions based on the information they gather.
#
# 4. **Memory**: Langchain allows applications to maintain state or memory, enabling them to remember previous interactions and provide more contextually relevant responses over time.
#
# 5. **Data Connectors**: It offers integration with various data sources, including APIs, databases, and file systems, allowing applications to fetch and utilize external data seamlessly.
#
# 6. **Prompt Templates**: Langchain provides a way to create and manage prompt templates, making it easier to generate dynamic prompts tailored to specific user queries or contexts.
#
# 7. **Evaluation**: The framework includes tools for evaluating the performance of LLMs, which can help developers refine their applications and improve response quality.
#
# 8. **Community and Ecosystem**: Being open source, Langchain has a growing community and ecosystem, with ongoing contributions and resources available for developers to leverage.
#
# These features make Langchain a versatile platform for building a wide range of applications, from chatbots to more complex LLM-powered systems.
