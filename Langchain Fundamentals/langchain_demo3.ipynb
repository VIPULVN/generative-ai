# %%
from huggingface_hub import InferenceClient

# %%
api_token = "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"

# %%
# Initialize the inference Client
client = InferenceClient(
    model = "mistralai/Mistral-7B-Instruct-v0.1",
    token = api_token
)

# %%
response = client.text_generation("tell me about rules of cricket sport.", max_new_tokens=256, temperature = .5)

# %%
print(response)
# Out:
# ## Answer (1)
#
# Cricket is played by two teams, with each team consisting of 11 players. The objective of the game is to score as many runs as possible while trying to prevent the opposing team from scoring.
#
# The pitch is a rectangular strip of grass, with a small rubber ball. The ball is bowled by one team and batted by the other. The batsman tries to hit the ball and score runs by running between the two end posts.
#
# The game is played in an over, which consists of six deliveries. The bowler delivers the ball from one end of the pitch, and the batsman tries to hit it. If the ball is not hit, the batsman runs to the other end post and scores a run.
#
# The game is also played in an inning, which consists of two overs. The team that scores the most runs in an inning wins.
#
# ...
