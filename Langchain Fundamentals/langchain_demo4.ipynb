# %%
pip install langchain-openai

# %%
# ChatOpenAI: This is the langchain wrapper for OpenAI chat models
from langchain_openai import ChatOpenAI
import os

# %%
os.environ["OPENAI_API_KEY"] = ""

# %%
# Initialize OpenAI chat model

chat_model = ChatOpenAI(
    model_name = "gpt-4o-mini",
    temperature = .5
)

# %%
response = chat_model.invoke("Explain LangChain in simple terms.")

# %%
response
# Out:
# AIMessage(content='AQE can refer to several different things depending on the context. Here are a few possibilities:\n\n1. **Automated Query Expansion (AQE):** In the context of information retrieval and search engines, AQE refers to techniques used to improve search results by automatically expanding search queries with additional terms.\n\n2. **Association for Quality Education (AQE):** This is an organization in Northern Ireland that administers the Common Entrance Assessment (CEA) used by some grammar schools for student admissions.\n\n3. **AQE (Air Quality Engineering):** A company or term related to the engineering and technology field that deals with air quality control and air filtration systems.\n\n4. **Adaptive Query Execution (AQE):** In the context of data processing and big data frameworks like Apache Spark, AQE refers to a set of techniques used to optimize query execution plans based on runtime statistics.\n\nIf you have a specific context in mind, let me know, and I can provide more detailed information related to that area.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 201, 'prompt_tokens': 11, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_898ac29719', 'id': 'chatcmpl-BGmDgaig4fLCfEZK3IwIfbgpfZvNA', 'finish_reason': 'stop', 'logprobs': None}, id='run-0c02b23f-ecf6-4a08-bee3-5699c2bd627c-0', usage_metadata={'input_tokens': 11, 'output_tokens': 201, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
