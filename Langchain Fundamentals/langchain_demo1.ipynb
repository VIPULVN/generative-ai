# %%
pip install --upgrade langchain langchain-community

# %%
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

# %%
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-1.5B-Instruct", max_length = 512)

# %%
# wrap the pipeline in LangChain
# hugging face models like Llama, Mistral use Tranformers pipelines for inference
# HuggingFacePipeline acts as a bridge allowing langchain to communicate with these models
chat_model = HuggingFacePipeline(pipeline=pipe)
# Out:
# <ipython-input-4-809795560bef>:4: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   chat_model = HuggingFacePipeline(pipeline=pipe)

# %%
response = chat_model.invoke("Explain LangChain in simple terms?")

# %%
print(response)
# Out:
# Explain LangChain in simple terms?
# I am trying to understand the concept of "Langchain" as a term, but I don't have much knowledge about it. Can you explain what it means and how it works?
# The idea is that each piece of information or data has its own unique way of understanding and processing information. For example, a word like "dog" might be interpreted differently by different people based on their experiences and cultural background. This is why we need a system that can understand and process language in a more nuanced way.
# One possible solution is to create a "langchain", which is a complex network of interconnected neural networks that work together to understand and interpret language. Each node in the chain represents a different type of input or output, such as text, images, audio, etc. The chains are designed to learn from large amounts of data and adapt to new situations over time.
# ...
