# %%
pip install -qU langchain-openai langchain-core langchain
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 420.1/420.1 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.9 MB/s eta 0:00:00

# %%
# ChatOpenAI: This is the langchain wrapper for OpenAI chat models
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
# Initialize OpenAI chat model
chat_model = ChatOpenAI(
    model_name = "gpt-4o-mini",
    temperature = .7
)

# %%
prompt_template = ChatPromptTemplate.from_template(
    "Provide {fact_numbers} fun facts about {fact_topic}."
)

# %%
user_input = {
	"fact_numbers":3,
	"fact_topic": "ocean"
}

# %%
prompt = prompt_template.invoke(user_input)

# %%
print(prompt)
# Out:
# messages=[HumanMessage(content='Provide 3 fun facts about ocean.', additional_kwargs={}, response_metadata={})]

# %%
response = chat_model.invoke(prompt)

# %%
print(response.content)
# Out:
# Sure! Here are three fun facts about the ocean:
#
# 1. **Vastness of the Ocean**: The ocean covers more than 70% of the Earth's surface and contains about 97% of the planet's water. It's so vast that if you were to stack all the water in the ocean, it would create a layer about 12,000 feet deep!
#
# 2. **Deepest Point**: The Mariana Trench, located in the western Pacific Ocean, is the deepest part of the world's oceans, reaching depths of approximately 36,000 feet (over 10,900 meters). If you could drop Mount Everest into the trench, its peak would still be over a mile underwater!
#
# 3. **Marine Biodiversity**: The ocean is home to an estimated 230,000 known species, but scientists believe that there could be millions more yet to be discovered. This incredible biodiversity includes everything from the smallest plankton to the largest animal on Earth, the blue whale. In fact, some areas of the ocean, like coral reefs, are among the most diverse ecosystems on the planet.

# %%
chain = prompt_template | chat_model | StrOutputParser()

# %%
print(chain.invoke(user_input))
# Out:
# Sure! Here are three fun facts about the ocean:
#
# 1. **Vastness of the Ocean**: The ocean covers more than 70% of the Earth's surface and contains about 97% of the planet's water. It's so vast that if you could stack all of the Earth's mountains into the ocean, the water would still cover them!
#
# 2. **Deepest Point**: The Mariana Trench is the deepest part of the world's oceans, reaching depths of about 36,000 feet (over 11,000 meters). If Mount Everest were placed at the bottom of the trench, its peak would still be more than a mile underwater!
#
# 3. **Underwater Volcanoes**: The ocean floor is home to thousands of underwater volcanoes, and many of them are active. In fact, the majority of Earth's volcanic activity occurs underwater, and the Mid-Atlantic Ridge is the longest mountain range in the world, formed by these underwater volcanoes.
