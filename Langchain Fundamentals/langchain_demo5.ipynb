# %%
pip install -q langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 420.1/420.1 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.3 MB/s eta 0:00:00

# %%
# ChatOpenAI: This is the langchain wrapper for OpenAI chat models
from langchain_openai import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage
import os

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
# Initialize OpenAI chat model

chat_model = ChatOpenAI(
    model_name = "gpt-4o-mini",
    temperature = .8
)

# %%
message = [
    SystemMessage(content="You are a helpful AI assistant specialized in Apache Spark. Answer in a crisp manner."),
    HumanMessage(content="can you explain about AQE?")
]

# %%
response = chat_model.invoke(message)

# %%
response
# Out:
# AIMessage(content='Adaptive Query Execution (AQE) is a feature in Apache Spark that dynamically adjusts query execution plans based on runtime statistics. Introduced in Spark 3.0, AQE enhances performance by allowing Spark to optimize query plans during execution rather than relying solely on static optimization.\n\nKey aspects of AQE include:\n\n1. **Dynamic Join Strategies**: It can switch join types (e.g., from broadcast join to shuffle join) based on the size of the data.\n2. **Skew Join Handling**: AQE can detect data skew and repartition the data to alleviate skew issues.\n3. **Dynamic Partition Pruning**: It can prune partitions based on runtime data to reduce the amount of data processed.\n\nOverall, AQE improves resource utilization and query performance by making execution more adaptive to the actual data characteristics encountered during processing.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 168, 'prompt_tokens': 35, 'total_tokens': 203, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b376dfbbd5', 'id': 'chatcmpl-BGmLxAVarTx758iEgyC3umfFDobBq', 'finish_reason': 'stop', 'logprobs': None}, id='run-0eef5a48-ee07-4863-93ea-fe35aca31ee1-0', usage_metadata={'input_tokens': 35, 'output_tokens': 168, 'total_tokens': 203, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
